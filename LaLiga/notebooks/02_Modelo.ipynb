# %% [markdown]
# # 02. Modelado Predictivo — LaLiga
# ## Objetivo
# Entrenar el modelo XGBoost con calibración isotónica sobre el dataset completo (2010–2024)
# y guardar `modelo_v3_calibrado.joblib` para usar en producción.
# La optimización de hiperparámetros se realiza con Optuna sobre un conjunto de validación
# walk-forward (out-of-sample, sin data leakage).

# %%
# %pip install pandas numpy joblib xgboost scikit-learn optuna
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.0.1)
# Requirement already satisfied: numpy in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.4.3)
# Requirement already satisfied: joblib in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.5.3)
# Requirement already satisfied: xgboost in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.2.0)
# Requirement already satisfied: scikit-learn in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.8.0)
# Requirement already satisfied: optuna in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from xgboost) (1.17.1)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optuna) (1.18.4)
# Requirement already satisfied: colorlog in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optuna) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optuna) (26.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optuna) (2.0.48)
# Requirement already satisfied: tqdm in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: greenlet>=1 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sqlalchemy>=1.4.2->optuna) (3.3.2)
# Requirement already satisfied: colorama in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\emili\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import joblib
import warnings
warnings.filterwarnings('ignore')
from xgboost import XGBClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import log_loss, accuracy_score, brier_score_loss
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

DATA_PATH  = '../data/df_final_clean.csv'
MODEL_OUT  = '../modelo_v3_calibrado.joblib'

FEATURES = [
    'Home_Elo_Calc','Away_Elo_Calc','Elo_Diff',
    'Home_Market_Value','Away_Market_Value','Log_Value_Diff',
    'Diff_FIFA_Ova','Diff_FIFA_Mid','Diff_FIFA_Def','Diff_FIFA_Att',
    'Home_Streak_L5','Away_Streak_L5',
    'Home_H2H_L3','Away_H2H_L3',
]

df = pd.read_csv(DATA_PATH)
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date').reset_index(drop=True)
for c in FEATURES:
    if c in df.columns:
        df[c] = pd.to_numeric(df[c], errors='coerce').fillna(0)

df = df.dropna(subset=FEATURES + ['Target'])
print(f'Dataset: {len(df)} partidos | Temporadas: {sorted(df["Season"].unique())}')
# Out:
# Dataset: 5748 partidos | Temporadas: [np.int64(2010), np.int64(2011), np.int64(2012), np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023), np.int64(2024)]

# %% [markdown]
# ## 1. División train / test
# **Importante**: el test es la temporada 2024 (última). El modelo nunca la ve durante el entrenamiento.
# Las temporadas 2010–2023 se usan para optimización + entrenamiento final.

# %%
TEST_SEASON  = 2024
TRAIN_SEASONS = [s for s in df['Season'].unique() if s < TEST_SEASON]

tr_mask = df['Season'].isin(TRAIN_SEASONS)
te_mask = df['Season'] == TEST_SEASON

X_train = df.loc[tr_mask, FEATURES].values
y_train = df.loc[tr_mask, 'Target'].values
X_test  = df.loc[te_mask, FEATURES].values
y_test  = df.loc[te_mask, 'Target'].values

print(f'Train: {len(X_train)} partidos ({TRAIN_SEASONS[0]}-{TRAIN_SEASONS[-1]})')
print(f'Test : {len(X_test)} partidos ({TEST_SEASON})')
print(f'Distribucion train: H={np.mean(y_train==2):.1%}  D={np.mean(y_train==1):.1%}  A={np.mean(y_train==0):.1%}')
# Out:
# Train: 5320 partidos (2010-2023)
# Test : 428 partidos (2024)
# Distribucion train: H=46.6%  D=25.0%  A=28.3%

# %% [markdown]
# ## 2. Optimización de hiperparámetros con Optuna
# Minimizamos Log-Loss en validación walk-forward interna (5 folds de 1 temporada cada uno).
# Usamos las temporadas 2019–2023 para el proceso de optimización.

# %%
# Walk-forward interno para Optuna: ultimas 6 temporadas del train
opt_seasons = sorted(TRAIN_SEASONS)[-6:]
df_opt = df[df['Season'].isin(opt_seasons)].reset_index(drop=True)
X_opt  = df_opt[FEATURES].values
y_opt  = df_opt['Target'].values
s_opt  = df_opt['Season'].values
unique_s = sorted(df_opt['Season'].unique())

def objective(trial):
    params = {
        'objective':        'multi:softprob',
        'num_class':        3,
        'max_depth':        trial.suggest_int('max_depth', 2, 6),
        'learning_rate':    trial.suggest_float('learning_rate', 0.01, 0.15, log=True),
        'n_estimators':     trial.suggest_int('n_estimators', 100, 400),
        'subsample':        trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'reg_alpha':        trial.suggest_float('reg_alpha', 0.0, 2.0),
        'reg_lambda':       trial.suggest_float('reg_lambda', 0.5, 3.0),
        'random_state': 42, 'verbosity': 0, 'n_jobs': -1,
    }
    losses = []
    # Walk-forward: cada fold usa todas las temporadas anteriores como train
    for i in range(1, len(unique_s)):
        tr_s  = unique_s[:i]
        val_s = unique_s[i]
        tr  = np.isin(s_opt, tr_s)
        val = s_opt == val_s
        m = XGBClassifier(**params)
        m.fit(X_opt[tr], y_opt[tr])
        losses.append(log_loss(y_opt[val], m.predict_proba(X_opt[val])))
    return np.mean(losses)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50, show_progress_bar=True)
print(f'Mejor Log-Loss: {study.best_value:.4f}')
print(f'Mejores params: {study.best_params}')
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best trial: 42. Best value: 0.99668: 100%|██████████| 50/50 [01:23<00:00,  1.67s/it]
# Mejor Log-Loss: 0.9967
# Mejores params: {'max_depth': 2, 'learning_rate': 0.01572350966414925, 'n_estimators': 235, 'subsample': 0.8285132386889069, 'colsample_bytree': 0.6691580763896812, 'reg_alpha': 1.326275403276264, 'reg_lambda': 0.5916171579541396}

# %% [markdown]
# ## 3. Entrenamiento final y calibración isotónica

# %%
best = study.best_params.copy()
best.update({'objective':'multi:softprob','num_class':3,
             'random_state':42,'verbosity':0,'n_jobs':-1})

base_model  = XGBClassifier(**best)
final_model = CalibratedClassifierCV(base_model, method='isotonic', cv=3)
final_model.fit(X_train, y_train)

# Evaluacion en test
probs = final_model.predict_proba(X_test)
preds = final_model.predict(X_test)
acc   = accuracy_score(y_test, preds)
ll    = log_loss(y_test, probs)

# Brier score para victoria local (clase 2)
classes = list(final_model.classes_)
p_home  = probs[:, classes.index(2)]
brier   = brier_score_loss((y_test == 2).astype(int), p_home)

print('=' * 45)
print('EVALUACION EN TEST (2024, out-of-sample)')
print('=' * 45)
print(f'  Accuracy : {acc:.2%}')
print(f'  Log-Loss : {ll:.4f}  (referencia naive: ~1.099)')
print(f'  Brier(H) : {brier:.4f}  (menor = mejor calibracion)')
# Out:
# =============================================
# EVALUACION EN TEST (2024, out-of-sample)
# =============================================
#   Accuracy : 51.64%
#   Log-Loss : 0.9723  (referencia naive: ~1.099)
#   Brier(H) : 0.2093  (menor = mejor calibracion)

# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\emili\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\emili\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 4. Curva de calibración
# Comprobamos que las probabilidades predichas se corresponden con las frecuencias reales.
# Un modelo bien calibrado sigue la diagonal y=x.

# %%
import matplotlib.pyplot as plt
from sklearn.calibration import calibration_curve

fig, axes = plt.subplots(1, 3, figsize=(14, 4))
outcome_names = {0: 'Victoria visitante (A)', 1: 'Empate (D)', 2: 'Victoria local (H)'}
colors = ['steelblue', 'goldenrod', 'tomato']

for idx, (cls, name, color) in enumerate(zip([2, 1, 0],
    ['Victoria local (H)', 'Empate (D)', 'Victoria visit. (A)'], colors)):
    p_cls = probs[:, classes.index(cls)]
    y_bin = (y_test == cls).astype(int)
    prob_true, prob_pred = calibration_curve(y_bin, p_cls, n_bins=8, strategy='quantile')
    ax = axes[idx]
    ax.plot([0,1],[0,1], 'k--', alpha=0.4, label='Perfecta')
    ax.plot(prob_pred, prob_true, 'o-', color=color, label='Modelo')
    ax.set_title(name)
    ax.set_xlabel('Prob. predicha')
    ax.set_ylabel('Freq. real')
    ax.legend(); ax.grid(alpha=0.3)

plt.suptitle('Curvas de calibración — Test 2024', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig('../results/calibracion_2024.png', dpi=120, bbox_inches='tight')
plt.show()
print('Guardado: results/calibracion_2024.png')
# Out:
# Guardado: results/calibracion_2024.png

# %% [markdown]
# ## 5. Importancia de features

# %%
# Extraer importancias del estimador base (primer calibrador)
import pandas as pd
base = final_model.calibrated_classifiers_[0].estimator
fi   = pd.Series(base.feature_importances_, index=FEATURES).sort_values(ascending=True)

fig, ax = plt.subplots(figsize=(8, 6))
fi.plot(kind='barh', ax=ax, color='steelblue')
ax.set_title('Importancia de features (XGBoost, gain)', fontweight='bold')
ax.set_xlabel('Importancia relativa')
ax.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.savefig('../results/feature_importance_v3.png', dpi=120, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Guardar modelo

# %%
joblib.dump(final_model, MODEL_OUT)
print(f'Modelo guardado: {MODEL_OUT}')

# Guardar tambien los mejores params para reproducibilidad
import json
with open('../results/best_params.json', 'w') as f:
    json.dump(study.best_params, f, indent=2)
print('Params guardados: results/best_params.json')
# Out:
# Modelo guardado: ../modelo_v3_calibrado.joblib
# Params guardados: results/best_params.json
